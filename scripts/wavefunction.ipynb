# %% [markdown]
# # Wavefunction and intensity
# Plot one stored physical-space frame.

# %%
from pathlib import Path
import matplotlib.pyplot as plt
from sh1d_plotting import available_frames, plot_wavefunction
DATA_DIRECTORY = Path('../data/quickstart')
FRAME = available_frames(DATA_DIRECTORY)[-1]

# %%
plot_wavefunction(DATA_DIRECTORY, FRAME)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Time diagnostics
# Inspect total energy and wave action over a run.

# %%
from pathlib import Path
import matplotlib.pyplot as plt
from sh1d_plotting import plot_diagnostics
OUTPUT_DIRECTORY = Path('../output/quickstart')

# %%
plot_diagnostics(OUTPUT_DIRECTORY)
plt.tight_layout()
plt.show()

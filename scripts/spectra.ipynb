# %% [markdown]
# # Wave-action spectrum
# Compare an instantaneous spectrum with its running average.

# %%
from pathlib import Path
import matplotlib.pyplot as plt
from sh1d_plotting import load_csv, plot_spectrum
OUTPUT_DIRECTORY = Path('../output/quickstart')
FRAME = int(load_csv(OUTPUT_DIRECTORY / 'spectra.csv')['frame'][-1])

# %%
plot_spectrum(OUTPUT_DIRECTORY, FRAME)
plt.tight_layout()
plt.show()
